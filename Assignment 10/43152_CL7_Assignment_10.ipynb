# %% [markdown]
# **Name**: Vedant Puranik
#
# **Roll No.**: 43152
#
# **Lab**: CL7
#
# **Batch**: R9
#
# **Assignment 10**: Neural Network Implementation and Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from google.colab import files
import io
import warnings
warnings.filterwarnings('ignore')

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-e5e3a91f-6eab-44d9-a412-7064530b6fbf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5e3a91f-6eab-44d9-a412-7064530b6fbf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
df = pd.read_csv(io.BytesIO(data['data.csv']))
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(columns=['Unnamed: 32','id'],inplace=True)

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 31)

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
sns.countplot(df.diagnosis.values,label='count')

# %%
encode_diagnosis = {'diagnosis':{'B':0,'M':1}}

# %%
df.replace(encode_diagnosis,inplace=True)

# %%
df = df[[c for c in df if c not in ['diagnosis']] + ['diagnosis']]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# Features highly correlated with diagnosis:
#
# radius_mean, permiter_mean, area_mean, compactness_mean, concavity mean, concave_points_mean, radius_worst, perimeter_worst, area_worst, concavity_worst, concave_points_worst

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
bestfeatures = SelectKBest(score_func=chi2, k=20)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']
print(featureScores.nlargest(20,'Score'))
# Out:
#                 Features          Score
# 23            area_worst  112598.431564
# 3              area_mean   53991.655924
# 13               area_se    8758.504705
# 22       perimeter_worst    3665.035416
# 2         perimeter_mean    2011.102864
# 20          radius_worst     491.689157
# 0            radius_mean     266.104917
# 12          perimeter_se     250.571896
# 21         texture_worst     174.449400
# 1           texture_mean      93.897508
# 26       concavity_worst      39.516915
# 10             radius_se      34.675247
# 6         concavity_mean      19.712354
# 25     compactness_worst      19.314922
# 27  concave points_worst      13.485419
# 7    concave points_mean      10.544035
# 5       compactness_mean       5.403075
# 28        symmetry_worst       1.298861
# 16          concavity_se       1.044718
# 15        compactness_se       0.613785

# %% [markdown]
# **Without feature selection**

# %%
model = Sequential()
model.add(Dense(40,input_dim=30,activation='relu'))
model.add(Dense(20,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X,y,epochs=100,batch_size=10,validation_split=0.2)
# Out:
# Epoch 1/100
# 46/46 [==============================] - 0s 6ms/step - loss: 14.4858 - accuracy: 0.4440 - val_loss: 0.8348 - val_accuracy: 0.7895
# Epoch 2/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2950 - accuracy: 0.8945 - val_loss: 0.2400 - val_accuracy: 0.9123
# Epoch 3/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1898 - accuracy: 0.9231 - val_loss: 0.1684 - val_accuracy: 0.9386
# Epoch 4/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.9077 - val_loss: 0.2298 - val_accuracy: 0.9035
# Epoch 5/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9033 - val_loss: 0.2429 - val_accuracy: 0.9123
# Epoch 6/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9165 - val_loss: 0.1852 - val_accuracy: 0.9211
# Epoch 7/100
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.9407 - val_loss: 0.1913 - val_accuracy: 0.9474
# Epoch 8/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9231 - val_loss: 0.2440 - val_accuracy: 0.9386
# Epoch 9/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.9143 - val_loss: 0.2431 - val_accuracy: 0.9123
# Epoch 10/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.9209 - val_loss: 0.4538 - val_accuracy: 0.7982
# Epoch 11/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9253 - val_loss: 0.1691 - val_accuracy: 0.9386
# Epoch 12/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9099 - val_loss: 0.3196 - val_accuracy: 0.8684
# Epoch 13/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.9033 - val_loss: 0.8348 - val_accuracy: 0.6842
# Epoch 14/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9099 - val_loss: 0.1817 - val_accuracy: 0.9211
# Epoch 15/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9165 - val_loss: 0.4536 - val_accuracy: 0.8070
# Epoch 16/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8945 - val_loss: 0.1816 - val_accuracy: 0.9298
# Epoch 17/100
# 46/46 [==============================] - 0s 1ms/step - loss: 0.2086 - accuracy: 0.9187 - val_loss: 0.1701 - val_accuracy: 0.9298
# Epoch 18/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9055 - val_loss: 0.2283 - val_accuracy: 0.9211
# Epoch 19/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2152 - accuracy: 0.9275 - val_loss: 0.1904 - val_accuracy: 0.9386
# Epoch 20/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1659 - accuracy: 0.9275 - val_loss: 0.3265 - val_accuracy: 0.8509
# Epoch 21/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2560 - accuracy: 0.9055 - val_loss: 0.1858 - val_accuracy: 0.9474
# Epoch 22/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.9187 - val_loss: 0.2056 - val_accuracy: 0.9211
# Epoch 23/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2026 - accuracy: 0.9319 - val_loss: 0.1833 - val_accuracy: 0.9386
# Epoch 24/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9209 - val_loss: 0.2146 - val_accuracy: 0.9211
# Epoch 25/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.9187 - val_loss: 0.2719 - val_accuracy: 0.8947
# Epoch 26/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9275 - val_loss: 0.1797 - val_accuracy: 0.9386
# Epoch 27/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 0.9187 - val_loss: 0.2464 - val_accuracy: 0.8947
# Epoch 28/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.8945 - val_loss: 0.1709 - val_accuracy: 0.9298
# Epoch 29/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3653 - accuracy: 0.8989 - val_loss: 0.1838 - val_accuracy: 0.9298
# Epoch 30/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8703 - val_loss: 0.4305 - val_accuracy: 0.9298
# Epoch 31/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.9077 - val_loss: 0.7724 - val_accuracy: 0.7544
# Epoch 32/100
# 46/46 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.9319 - val_loss: 0.1876 - val_accuracy: 0.9386
# Epoch 33/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2226 - accuracy: 0.9209 - val_loss: 0.1935 - val_accuracy: 0.9386
# Epoch 34/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9341 - val_loss: 0.1730 - val_accuracy: 0.9474
# Epoch 35/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1870 - accuracy: 0.9363 - val_loss: 0.1760 - val_accuracy: 0.9386
# Epoch 36/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2074 - accuracy: 0.9121 - val_loss: 0.2967 - val_accuracy: 0.8684
# Epoch 37/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9275 - val_loss: 0.4673 - val_accuracy: 0.8070
# Epoch 38/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9319 - val_loss: 0.1619 - val_accuracy: 0.9386
# Epoch 39/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9165 - val_loss: 0.2074 - val_accuracy: 0.9474
# Epoch 40/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.9165 - val_loss: 0.7431 - val_accuracy: 0.7018
# Epoch 41/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9077 - val_loss: 0.2882 - val_accuracy: 0.8772
# Epoch 42/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1852 - accuracy: 0.9275 - val_loss: 0.2386 - val_accuracy: 0.9035
# Epoch 43/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9341 - val_loss: 0.4788 - val_accuracy: 0.8070
# Epoch 44/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9341 - val_loss: 0.1852 - val_accuracy: 0.9474
# Epoch 45/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9363 - val_loss: 0.1668 - val_accuracy: 0.9386
# Epoch 46/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9187 - val_loss: 0.2000 - val_accuracy: 0.9298
# Epoch 47/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1970 - accuracy: 0.9209 - val_loss: 0.1657 - val_accuracy: 0.9474
# Epoch 48/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1867 - accuracy: 0.9297 - val_loss: 0.1439 - val_accuracy: 0.9298
# Epoch 49/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.9187 - val_loss: 0.1699 - val_accuracy: 0.9474
# Epoch 50/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9121 - val_loss: 0.1641 - val_accuracy: 0.9474
# Epoch 51/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2101 - accuracy: 0.9253 - val_loss: 0.1632 - val_accuracy: 0.9474
# Epoch 52/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1990 - accuracy: 0.9209 - val_loss: 0.1623 - val_accuracy: 0.9474
# Epoch 53/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.9209 - val_loss: 0.1619 - val_accuracy: 0.9474
# Epoch 54/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1922 - accuracy: 0.9253 - val_loss: 0.2111 - val_accuracy: 0.9123
# Epoch 55/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1897 - accuracy: 0.9121 - val_loss: 0.1526 - val_accuracy: 0.9298
# Epoch 56/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2050 - accuracy: 0.9231 - val_loss: 0.1558 - val_accuracy: 0.9561
# Epoch 57/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1732 - accuracy: 0.9297 - val_loss: 0.1722 - val_accuracy: 0.9386
# Epoch 58/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.9363 - val_loss: 0.2398 - val_accuracy: 0.9474
# Epoch 59/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9363 - val_loss: 0.2397 - val_accuracy: 0.9211
# Epoch 60/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 0.9209 - val_loss: 0.4515 - val_accuracy: 0.7982
# Epoch 61/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.8901 - val_loss: 0.1931 - val_accuracy: 0.9474
# Epoch 62/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1669 - accuracy: 0.9385 - val_loss: 0.2380 - val_accuracy: 0.9035
# Epoch 63/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1331 - accuracy: 0.9407 - val_loss: 0.7618 - val_accuracy: 0.7105
# Epoch 64/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1733 - accuracy: 0.9319 - val_loss: 0.1460 - val_accuracy: 0.9386
# Epoch 65/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9429 - val_loss: 0.7682 - val_accuracy: 0.7281
# Epoch 66/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.9363 - val_loss: 0.2920 - val_accuracy: 0.8772
# Epoch 67/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9495 - val_loss: 0.1623 - val_accuracy: 0.9386
# Epoch 68/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9385 - val_loss: 0.4304 - val_accuracy: 0.8246
# Epoch 69/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9407 - val_loss: 0.3187 - val_accuracy: 0.8596
# Epoch 70/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1318 - accuracy: 0.9538 - val_loss: 0.1684 - val_accuracy: 0.9474
# Epoch 71/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9209 - val_loss: 0.3794 - val_accuracy: 0.8509
# Epoch 72/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1561 - accuracy: 0.9341 - val_loss: 0.1662 - val_accuracy: 0.9474
# Epoch 73/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2051 - accuracy: 0.9275 - val_loss: 0.4506 - val_accuracy: 0.8246
# Epoch 74/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1311 - accuracy: 0.9451 - val_loss: 0.1364 - val_accuracy: 0.9561
# Epoch 75/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9319 - val_loss: 0.1621 - val_accuracy: 0.9298
# Epoch 76/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1739 - accuracy: 0.9385 - val_loss: 0.2115 - val_accuracy: 0.9298
# Epoch 77/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1493 - accuracy: 0.9429 - val_loss: 0.1700 - val_accuracy: 0.9561
# Epoch 78/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1769 - accuracy: 0.9407 - val_loss: 0.1901 - val_accuracy: 0.9298
# Epoch 79/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.9407 - val_loss: 0.3206 - val_accuracy: 0.8596
# Epoch 80/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 0.9363 - val_loss: 0.1467 - val_accuracy: 0.9474
# Epoch 81/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9385 - val_loss: 0.1629 - val_accuracy: 0.9561
# Epoch 82/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 0.9209 - val_loss: 0.1691 - val_accuracy: 0.9474
# Epoch 83/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 0.9429 - val_loss: 0.2568 - val_accuracy: 0.8947
# Epoch 84/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1723 - accuracy: 0.9341 - val_loss: 0.2365 - val_accuracy: 0.8947
# Epoch 85/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.9319 - val_loss: 0.2824 - val_accuracy: 0.8860
# Epoch 86/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9451 - val_loss: 0.1396 - val_accuracy: 0.9474
# Epoch 87/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1713 - accuracy: 0.9363 - val_loss: 0.1278 - val_accuracy: 0.9386
# Epoch 88/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 0.9385 - val_loss: 0.2250 - val_accuracy: 0.9035
# Epoch 89/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1471 - accuracy: 0.9407 - val_loss: 0.2195 - val_accuracy: 0.9298
# Epoch 90/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.9341 - val_loss: 0.2247 - val_accuracy: 0.9123
# Epoch 91/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9275 - val_loss: 0.1603 - val_accuracy: 0.9474
# Epoch 92/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9253 - val_loss: 0.1550 - val_accuracy: 0.9474
# Epoch 93/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9341 - val_loss: 0.3551 - val_accuracy: 0.8596
# Epoch 94/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1202 - accuracy: 0.9560 - val_loss: 0.4627 - val_accuracy: 0.7982
# Epoch 95/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1495 - accuracy: 0.9429 - val_loss: 0.2360 - val_accuracy: 0.9123
# Epoch 96/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9385 - val_loss: 0.3763 - val_accuracy: 0.8509
# Epoch 97/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.9495 - val_loss: 0.2092 - val_accuracy: 0.9211
# Epoch 98/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9429 - val_loss: 0.1512 - val_accuracy: 0.9474
# Epoch 99/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.9297 - val_loss: 0.1728 - val_accuracy: 0.9474
# Epoch 100/100
# 46/46 [==============================] - 0s 2ms/step - loss: 0.2541 - accuracy: 0.9143 - val_loss: 0.2342 - val_accuracy: 0.9211

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 40)                1240
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                820
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 2,281
# Trainable params: 2,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1516 - accuracy: 0.9402
# Accuracy: 94.02

# %%
predictions = model.predict_classes(X)
# Out:
# WARNING:tensorflow:From <ipython-input-23-cc892bcd26bd>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
for i in range(0,10):
  print("{}. Prediction => {}, Actual => [{}]".format(i,predictions[i],y[i]))
# Out:
# 0. Prediction => [1], Actual => [1]
# 1. Prediction => [1], Actual => [1]
# 2. Prediction => [1], Actual => [1]
# 3. Prediction => [1], Actual => [1]
# 4. Prediction => [1], Actual => [1]
# 5. Prediction => [1], Actual => [1]
# 6. Prediction => [1], Actual => [1]
# 7. Prediction => [1], Actual => [1]
# 8. Prediction => [1], Actual => [1]
# 9. Prediction => [1], Actual => [1]

# %%
train_loss = hist.history['loss']
val_loss = hist.history['val_loss']
train_acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(100)

# %%
plt.figure(figsize=(5,5))
plt.plot(epochs,train_loss)
plt.plot(epochs,val_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Trend')
plt.legend(['Train Loss','Validation Loss'])
plt.show()

# %%
#save and load model
'''
model.save('cancer_model.h5')
from keras.models import load_model
model = load_model('cancer_model.h5')
'''
# Out:
# "\nmodel.save('cancer_model.h5')\nfrom keras.models import load_model\nmodel = load_model('cancer_model.h5')\n"

# %% [markdown]
# **With feature selection**

# %%
column_vals = ['radius_mean','perimeter_mean','area_mean','compactness_mean','concavity_mean','concave points_mean','radius_worst','perimeter_worst','area_worst','concavity_worst','concave points_worst']

# %%
X_reduced = X.loc[:,column_vals]

# %%
X_reduced
# Out:
#      radius_mean  perimeter_mean  ...  concavity_worst  concave points_worst
# 0          17.99          122.80  ...           0.7119                0.2654
# 1          20.57          132.90  ...           0.2416                0.1860
# 2          19.69          130.00  ...           0.4504                0.2430
# 3          11.42           77.58  ...           0.6869                0.2575
# 4          20.29          135.10  ...           0.4000                0.1625
# ..           ...             ...  ...              ...                   ...
# 564        21.56          142.00  ...           0.4107                0.2216
# 565        20.13          131.20  ...           0.3215                0.1628
# 566        16.60          108.30  ...           0.3403                0.1418
# 567        20.60          140.10  ...           0.9387                0.2650
# 568         7.76           47.92  ...           0.0000                0.0000
#
# [569 rows x 11 columns]

# %%
model_reduced = Sequential()
model_reduced.add(Dense(15,input_dim=11,activation='relu'))
model_reduced.add(Dense(20,activation='relu'))
model_reduced.add(Dense(8,activation='relu'))
model_reduced.add(Dense(1,activation='sigmoid'))
plot_model(model_reduced, to_file='model_reduced_plot.png', show_shapes=True, show_layer_names=True)

# %%
model_reduced.compile(loss='binary_crossentropy',optimizer='adam',metrics='accuracy')

# %%
hist_reduced = model_reduced.fit(X_reduced,y,epochs=50,batch_size=5,validation_split=0.2)
# Out:
# Epoch 1/50
# 91/91 [==============================] - 0s 3ms/step - loss: 4.2763 - accuracy: 0.6835 - val_loss: 0.8865 - val_accuracy: 0.7193
# Epoch 2/50
# 91/91 [==============================] - 0s 2ms/step - loss: 1.1371 - accuracy: 0.7473 - val_loss: 0.8637 - val_accuracy: 0.6754
# Epoch 3/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.7086 - accuracy: 0.8462 - val_loss: 0.3298 - val_accuracy: 0.8860
# Epoch 4/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.6552 - accuracy: 0.8308 - val_loss: 0.2880 - val_accuracy: 0.8947
# Epoch 5/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8923 - val_loss: 1.5113 - val_accuracy: 0.5789
# Epoch 6/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8769 - val_loss: 0.2268 - val_accuracy: 0.9298
# Epoch 7/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8923 - val_loss: 0.2587 - val_accuracy: 0.9474
# Epoch 8/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.5663 - accuracy: 0.8615 - val_loss: 0.3261 - val_accuracy: 0.9298
# Epoch 9/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8967 - val_loss: 0.3718 - val_accuracy: 0.8772
# Epoch 10/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3559 - accuracy: 0.8989 - val_loss: 0.2387 - val_accuracy: 0.9474
# Epoch 11/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.8527 - val_loss: 0.6836 - val_accuracy: 0.9123
# Epoch 12/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3483 - accuracy: 0.9033 - val_loss: 0.3904 - val_accuracy: 0.8772
# Epoch 13/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.4270 - accuracy: 0.8835 - val_loss: 0.2254 - val_accuracy: 0.9298
# Epoch 14/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3755 - accuracy: 0.8901 - val_loss: 0.2205 - val_accuracy: 0.9298
# Epoch 15/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2934 - accuracy: 0.8967 - val_loss: 0.2197 - val_accuracy: 0.9211
# Epoch 16/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3637 - accuracy: 0.8967 - val_loss: 0.3127 - val_accuracy: 0.9035
# Epoch 17/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2292 - accuracy: 0.9099 - val_loss: 0.2505 - val_accuracy: 0.9123
# Epoch 18/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2873 - accuracy: 0.9165 - val_loss: 0.2142 - val_accuracy: 0.9298
# Epoch 19/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3909 - accuracy: 0.8901 - val_loss: 0.7016 - val_accuracy: 0.7807
# Epoch 20/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.4189 - accuracy: 0.8615 - val_loss: 0.6664 - val_accuracy: 0.7982
# Epoch 21/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3682 - accuracy: 0.9011 - val_loss: 0.2792 - val_accuracy: 0.9298
# Epoch 22/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.4659 - accuracy: 0.8813 - val_loss: 0.6014 - val_accuracy: 0.8070
# Epoch 23/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3048 - accuracy: 0.9033 - val_loss: 0.3128 - val_accuracy: 0.8947
# Epoch 24/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2766 - accuracy: 0.9121 - val_loss: 0.4338 - val_accuracy: 0.8596
# Epoch 25/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8989 - val_loss: 0.4261 - val_accuracy: 0.8684
# Epoch 26/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8835 - val_loss: 0.2996 - val_accuracy: 0.8947
# Epoch 27/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9253 - val_loss: 0.2362 - val_accuracy: 0.9123
# Epoch 28/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.9011 - val_loss: 0.4109 - val_accuracy: 0.8772
# Epoch 29/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.2669 - accuracy: 0.9099 - val_loss: 0.6354 - val_accuracy: 0.7895
# Epoch 30/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3269 - accuracy: 0.8835 - val_loss: 0.5424 - val_accuracy: 0.9211
# Epoch 31/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3701 - accuracy: 0.9011 - val_loss: 0.5202 - val_accuracy: 0.8333
# Epoch 32/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.9033 - val_loss: 0.3569 - val_accuracy: 0.8772
# Epoch 33/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2783 - accuracy: 0.9143 - val_loss: 0.2207 - val_accuracy: 0.9386
# Epoch 34/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.9099 - val_loss: 0.6466 - val_accuracy: 0.7895
# Epoch 35/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.9121 - val_loss: 0.2183 - val_accuracy: 0.9298
# Epoch 36/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3211 - accuracy: 0.9033 - val_loss: 0.2251 - val_accuracy: 0.9298
# Epoch 37/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2127 - accuracy: 0.9275 - val_loss: 1.0236 - val_accuracy: 0.6930
# Epoch 38/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3073 - accuracy: 0.9011 - val_loss: 0.2672 - val_accuracy: 0.9123
# Epoch 39/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2697 - accuracy: 0.9143 - val_loss: 0.2233 - val_accuracy: 0.9211
# Epoch 40/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9187 - val_loss: 0.2179 - val_accuracy: 0.9386
# Epoch 41/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3097 - accuracy: 0.9077 - val_loss: 0.4955 - val_accuracy: 0.8070
# Epoch 42/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.3155 - accuracy: 0.8901 - val_loss: 1.1349 - val_accuracy: 0.6404
# Epoch 43/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3622 - accuracy: 0.8769 - val_loss: 0.3064 - val_accuracy: 0.8947
# Epoch 44/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.9143 - val_loss: 0.2408 - val_accuracy: 0.9474
# Epoch 45/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2035 - accuracy: 0.9297 - val_loss: 0.3266 - val_accuracy: 0.9035
# Epoch 46/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2065 - accuracy: 0.9341 - val_loss: 0.2238 - val_accuracy: 0.9123
# Epoch 47/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.2354 - accuracy: 0.9385 - val_loss: 0.5971 - val_accuracy: 0.7895
# Epoch 48/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3405 - accuracy: 0.8967 - val_loss: 0.2374 - val_accuracy: 0.9123
# Epoch 49/50
# 91/91 [==============================] - 0s 1ms/step - loss: 0.3344 - accuracy: 0.8989 - val_loss: 0.3817 - val_accuracy: 0.8772
# Epoch 50/50
# 91/91 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9143 - val_loss: 0.2031 - val_accuracy: 0.9474

# %%
model_reduced.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 15)                180
# _________________________________________________________________
# dense_9 (Dense)              (None, 20)                320
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 168
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 677
# Trainable params: 677
# Non-trainable params: 0
# _________________________________________________________________

# %%
_, accuracy_ = model_reduced.evaluate(X_reduced, y)
print('Accuracy: %.2f' % (accuracy_*100))
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9227
# Accuracy: 92.27

# %%
preds = model_reduced.predict_classes(X_reduced)

# %%
for i in range(0,10):
  print("{}. Prediction => {}, Actual => [{}]".format(i,preds[i],y[i]))
# Out:
# 0. Prediction => [1], Actual => [1]
# 1. Prediction => [1], Actual => [1]
# 2. Prediction => [1], Actual => [1]
# 3. Prediction => [0], Actual => [1]
# 4. Prediction => [1], Actual => [1]
# 5. Prediction => [1], Actual => [1]
# 6. Prediction => [1], Actual => [1]
# 7. Prediction => [1], Actual => [1]
# 8. Prediction => [0], Actual => [1]
# 9. Prediction => [1], Actual => [1]

# %%
train_loss = hist_reduced.history['loss']
val_loss = hist_reduced.history['val_loss']
train_acc = hist_reduced.history['accuracy']
val_acc = hist_reduced.history['val_accuracy']
epochs = range(50)

# %%
plt.figure(figsize=(5,5))
plt.plot(epochs,train_loss)
plt.plot(epochs,val_loss)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Trend')
plt.legend(['Train Loss','Validation Loss'])
plt.show()
